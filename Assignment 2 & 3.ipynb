# %%
import pandas as pd

# %%
#load the csv file 
import pandas as pd
employee_attrition=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
employee_attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
import pandas as pd
employee_attrition=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
employee_attrition.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
employee_attrition2=employee_attrition.sort_values(by='DistanceFromHome',ascending=True)
cols = ['Attrition','Department','DistanceFromHome']
employee_attrition6=employee_attrition2[cols]
employee_attrition6[(employee_attrition6.Attrition=='Yes')&(employee_attrition6.Department=='Research & Development')]
# Out:
#      Attrition              Department  DistanceFromHome
# 1077       Yes  Research & Development                 1
# 217        Yes  Research & Development                 1
# 1279       Yes  Research & Development                 1
# 239        Yes  Research & Development                 1
# 800        Yes  Research & Development                 1
# ...        ...                     ...               ...
# 1006       Yes  Research & Development                28
# 792        Yes  Research & Development                29
# 271        Yes  Research & Development                29
# 204        Yes  Research & Development                29
# 259        Yes  Research & Development                29
#
# [133 rows x 3 columns]

# %%
# Show a breakdown of distance from home by job role and attrition.
employee_attrition2=employee_attrition.sort_values(by='DistanceFromHome',ascending=True)
cols = ['Attrition','Department','DistanceFromHome']
employee_attrition2[cols]
employee_attrition6=employee_attrition2[cols]
employee_attrition6[(employee_attrition6.Attrition=='Yes')]
employee_attrition6.groupby('Department').DistanceFromHome.agg(['count','mean','max','min'])
# Out:
#                         count      mean  max  min
# Department
# Human Resources            63  8.698413   26    1
# Research & Development    961  9.144641   29    1
# Sales                     446  9.365471   29    1

# %%
#  Compare average monthly income by education and attrition. We need the Monthly income column, Education column and attrition column

employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
employee_attrition3=employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition3[cols]
employee_attrition4=employee_attrition3[employee_attrition3.Education==1]
employee_attrition4
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition4[cols]
employee_attrition4.sort_values(by='Attrition')
employee_attrition5=employee_attrition4.sort_values(by='Attrition')
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition5[cols]
# Out:
#      Attrition  Education  MonthlyIncome
# 1318        No          1           3812
# 281         No          1           4907
# 825         No          1           5056
# 974         No          1           5071
# 80          No          1           5126
# ...        ...        ...            ...
# 171        Yes          1           2325
# 1271       Yes          1           2679
# 1201       Yes          1           3989
# 666        Yes          1           4171
# 513        Yes          1           1009
#
# [170 rows x 3 columns]

# %%
employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
employee_attrition3=employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition3[cols]
employee_attrition4=employee_attrition3[employee_attrition3.Education!=0]
employee_attrition4
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition4[cols]
employee_attrition4.sort_values(by='Attrition')
employee_attrition5=employee_attrition4.sort_values(by='Attrition')
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition5[cols]
employee_attrition5.groupby('Education').MonthlyIncome.agg(['count','mean','max','min'])
# Out:
#            count         mean    max   min
# Education
# 1            170  5640.570588  19973  1009
# 2            282  6226.645390  19613  1051
# 3            572  6517.263986  19926  1081
# 4            398  6832.402010  19999  1359
# 5             48  8277.645833  19586  2127

# %%
# Assignment 3 - Based on your analysis in Assignment 2, express your results in the form of the most 
appropriate visualization using any visualization library of your choice
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#employee_attrition8=employee_attrition6.groupby('Department').DistanceFromHome.agg(['count','mean','max','min'])
employee_attrition8=employee_attrition6.groupby('Department').DistanceFromHome.agg(['count'])
employee_attrition8.shape
employee_attrition8.columns
employee_attrition8.plot.bar()
# Out:
# <AxesSubplot:xlabel='Department'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#employee_attrition8=employee_attrition6.groupby('Department').DistanceFromHome.agg(['count','mean','max','min'])
employee_attrition9=employee_attrition6[(employee_attrition6.Attrition=='Yes')&(employee_attrition6.Department=='Research & Development')]
employee_attrition9.shape
employee_attrition9.columns
employee_attrition9.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
employee_attrition3=employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition3[cols]
employee_attrition4=employee_attrition3[employee_attrition3.Education!=0]
employee_attrition4
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition4[cols]
employee_attrition4.sort_values(by='Attrition')
employee_attrition5=employee_attrition4.sort_values(by='Attrition')
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition5[cols]
employee_attrition10=employee_attrition5.groupby('Education').MonthlyIncome.agg(['count'])
employee_attrition10
# Out:
#            count
# Education
# 1            170
# 2            282
# 3            572
# 4            398
# 5             48

# %%
employee_attrition10.plot.bar()
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
employee_attrition3=employee_attrition.sort_values(by='MonthlyIncome',ascending=True)
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition3[cols]
employee_attrition4=employee_attrition3[employee_attrition3.Education!=0]
employee_attrition4
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition4[cols]
employee_attrition4.sort_values(by='Attrition')
employee_attrition5=employee_attrition4.sort_values(by='Attrition')
cols = ['Attrition','Education','MonthlyIncome']
employee_attrition5[cols]
employee_attrition5[cols].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>
